# %%
import pandas as pd

df = pd.read_csv(r"D:\My Projects 1\Dataanalytics (begining)\Beginingdata files\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# # Fact : Normally for multidimenarray(eg arr[4][5]) when calling an element "row is first sq bracs then second = col"
# # But for dffataframe(df['Rank'][2] = Albania)  col first then row
# #
# # i can also use df.Rank instead of df['Rank']
# # So in dataframe only calling row use loc or iloc

# %%
df1 = df.set_index('Country')

# loc for accesing whatever index but iloc needs to be integer
df1.loc["India"]
# Out:
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# Continent                              Asia
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: India, dtype: object

# %%
df1.iloc[45]
# Out:
# Rank                                     124
# CCA3                                     CRI
# Capital                             San José
# Continent                      North America
# 2022 Population                    5180829.0
# 2020 Population                    5123105.0
# 2015 Population                    4895242.0
# 2010 Population                    4622252.0
# 2000 Population                    3979193.0
# 1990 Population                    3158253.0
# 1980 Population                    2414303.0
# 1970 Population                    1855697.0
# Area (km²)                           51100.0
# Density (per km²)                   101.3861
# Growth Rate                           1.0052
# World Population Percentage             0.06
# Name: Costa Rica, dtype: object

# %% [markdown]
# # Filtering elements of the Column (i.e hence affect entire rows of the col) along with the next Markdown

# %%
print(df['Rank']<10)
# prints the data whose above conditions is true
df[df['Rank']<10]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: Rank, Length: 234, dtype: bool
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %% [markdown]
# # Print df of the mentioned country and display df based on given string

# %%
# show df by checking dfcountry is in the list(useing isin method) 'india','brazil'
print(df[df['Country'] == 'India'])

df['Country'].isin(['India','Brazil','Andorra'])
# Out:
#     Rank CCA3 Country    Capital Continent  2022 Population  2020 Population  \
# 92     2  IND   India  New Delhi      Asia     1.417173e+09     1.396387e+09
#
#     2015 Population  2010 Population  2000 Population  1990 Population  \
# 92     1.322867e+09     1.240614e+09     1.059634e+09              NaN
#
#     1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 92              NaN      557501301.0   3287590.0           431.0675
#
#     Growth Rate  World Population Percentage
# 92       1.0068                        17.77
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: Country, Length: 234, dtype: bool

# %%
df[df['Country'].isin(['India','Brazil','China'])]
# Out:
#     Rank CCA3 Country    Capital      Continent  2022 Population  \
# 27     7  BRA  Brazil   Brasilia  South America     2.153135e+08
# 41     1  CHN   China    Beijing           Asia     1.425887e+09
# 92     2  IND   India  New Delhi           Asia     1.417173e+09
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 27     2.131963e+08     2.051882e+08     1.963535e+08     1.758737e+08
# 41     1.424930e+09     1.393715e+09     1.348191e+09     1.264099e+09
# 92     1.396387e+09     1.322867e+09     1.240614e+09     1.059634e+09
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 27     1.507064e+08      122288383.0       96369875.0   8515767.0
# 41     1.153704e+09      982372466.0      822534450.0   9706961.0
# 92              NaN              NaN      557501301.0   3287590.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 27            25.2841       1.0046                         2.70
# ...

# %%
# Here only containing cap Z
df[df['Country'].str.contains('Z')]
# Out:
#      Rank CCA3      Country     Capital Continent  2022 Population  \
# 146   123  NZL  New Zealand  Wellington   Oceania        5185288.0
# 232    63  ZMB       Zambia      Lusaka    Africa       20017675.0
# 233    74  ZWE     Zimbabwe      Harare    Africa       16320537.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 146        5061133.0        4590590.0        4346338.0        3855266.0
# 232       18927715.0              NaN       13792086.0        9891136.0
# 233       15669666.0       14154937.0       12839771.0       11834676.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 146        3397389.0        3147168.0        2824061.0    270467.0
# 232        7686401.0        5720438.0        4281671.0    752612.0
# 233       10113893.0        7049926.0        5202918.0    390757.0
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 146            19.1716       1.0108                         0.07
# ...

# %% [markdown]
# # Create new good looking df with index as Country

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %% [markdown]
# # To choose specifc rows or column i.e
# # Unlike above way we cannot provide condition
#
# # 1st cell similar to isin but more freedom
# # 2nd cell similar to contains checking for given string in only index

# %%
# if did axis 0 will give data of "Andorra and India" else columns "Ranks and continent"

df2.filter(items=['Andorra','India','Rank','Continent'], axis = 1 )
# Out:
#                    Rank Continent
# Country
# Afghanistan          36      Asia
# Albania             138    Europe
# Algeria              34    Africa
# American Samoa      213   Oceania
# Andorra             203    Europe
# ...                 ...       ...
# Wallis and Futuna   226   Oceania
# Western Sahara      172    Africa
# Yemen                46      Asia
# Zambia               63    Africa
# Zimbabwe             74    Africa
#
# [234 rows x 2 columns]

# %%
df2.filter(like='Ind', axis = 0 )
# Out:
#            Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# Country
# India         2  IND  New Delhi      Asia     1.417173e+09     1.396387e+09
# Indonesia     4  IDN    Jakarta      Asia     2.755013e+08     2.718580e+08
#
#            2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# India         1.322867e+09     1.240614e+09     1.059634e+09              NaN
# Indonesia     2.590920e+08     2.440162e+08     2.140724e+08      182159874.0
#
#            1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# India                  NaN      557501301.0   3287590.0           431.0675
# Indonesia      148177096.0      115228394.0   1904569.0           144.6529
#
#            Growth Rate  World Population Percentage
# Country
# India           1.0068                        17.77
# Indonesia       1.0064                         3.45

# %% [markdown]
# #
# # for showing onlt specific columns based on conditions

# %%
df2.query('Rank < 20 and Continent == "Asia"')
# Out:
#              Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# Country
# Bangladesh      8  BGD      Dhaka      Asia     1.711864e+08     1.674210e+08
# China           1  CHN    Beijing      Asia     1.425887e+09     1.424930e+09
# India           2  IND  New Delhi      Asia     1.417173e+09     1.396387e+09
# Indonesia       4  IDN    Jakarta      Asia     2.755013e+08     2.718580e+08
# Iran           17  IRN     Tehran      Asia     8.855057e+07     8.729019e+07
# Japan          11  JPN      Tokyo      Asia     1.239517e+08     1.252448e+08
# Pakistan        5  PAK  Islamabad      Asia     2.358249e+08     2.271967e+08
# Philippines    13  PHL     Manila      Asia     1.155590e+08     1.121910e+08
# Turkey         18  TUR     Ankara      Asia     8.534124e+07     8.413543e+07
# Vietnam        16  VNM      Hanoi      Asia     9.818686e+07     9.664868e+07
#
#              2015 Population  2010 Population  2000 Population  \
# Country
# ...

# %%
df2[(df2['Rank'] < 20) & (df2['Continent'].str.contains('As'))]
# Out:
#              Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# Country
# Bangladesh      8  BGD      Dhaka      Asia     1.711864e+08     1.674210e+08
# China           1  CHN    Beijing      Asia     1.425887e+09     1.424930e+09
# India           2  IND  New Delhi      Asia     1.417173e+09     1.396387e+09
# Indonesia       4  IDN    Jakarta      Asia     2.755013e+08     2.718580e+08
# Iran           17  IRN     Tehran      Asia     8.855057e+07     8.729019e+07
# Japan          11  JPN      Tokyo      Asia     1.239517e+08     1.252448e+08
# Pakistan        5  PAK  Islamabad      Asia     2.358249e+08     2.271967e+08
# Philippines    13  PHL     Manila      Asia     1.155590e+08     1.121910e+08
# Turkey         18  TUR     Ankara      Asia     8.534124e+07     8.413543e+07
# Vietnam        16  VNM      Hanoi      Asia     9.818686e+07     9.664868e+07
#
#              2015 Population  2010 Population  2000 Population  \
# Country
# ...

# %% [markdown]
# # For Sorting Columns based on numbers or letters in ascending or descending

# %%
df2.sort_values( by=['Rank'])

# %% [markdown]
# #
# # Q1) (Order by) to sort all whose whose rank is less than 10, based on Country name(i.e: a is 1st, b is 2nd)

# %%
top10_df = df[df['Rank'] <= 10]
top10_df.sort_values(by='Rank', ascending = False)

# df[df['Rank']<10].sort_values(by = ['Country','Rank',], ascending = [True,True])  

##NOTE:
# btw the second true in the list of ascending doesnt have any affect 
# THEREFORE making list doesnt make sense here for by and ascending
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 131    10  MEX         Mexico       Mexico City  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 131     1.275041e+08     1.259983e+08     1.201499e+08     1.125324e+08
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %%
# df.loc

# (in col)
# df['Country']
# for below two (checks cond and if true cover it with another df which will display true ones)
# df[Country].isin([l1,l2])  isin method init element of the col mentioned  
# str.contains   init string   

# df.query uses the above manipulation
# df.query( 'df[Country].str.contains([l1,l2]) and df[Rank] > 100' ) 

# df.filter( items )  init items = [list of row element or column element] what will be called depends on axis   
# df.filter( like )  filter elements based on string like above 

# df2.sort_values( by=['Continent'])
